# %%
# THEORY QUESTIONS AND ANSWERS

'''Q1. What is the difference betwen a function and a method in Python?

Ans:In Python, the terms function and method both refer to callable objects, but they differ in their context and usage:

Function:

A function is a block of reusable code that performs a specific task.
It is defined using the def keyword or the lambda keyword (for anonymous functions).
Functions can be defined outside of any class and are typically called directly by their name.

Method:

A method is a function that is associated with an object (specifically, an instance of a class) and is called on that object.
Methods are defined within a class and are typically used to manipulate the object's data or perform actions specific to that object.
When calling a method, the object (or instance) on which it operates is automatically passed as the first argument, usually named self.

Key Differences:

Scope: Functions are independent and not tied to an object, whereas methods are tied to an instance of a class.
Invocation: Functions are called by their name directly, while methods are called on an object, with the object being implicitly passed as the first argument.

In summary:

A function is defined outside a class and doesn't require an object to call.
A method is a function defined inside a class, and it is called on an instance of that class, with the instance passed as the first argument (self).

An examplary code is given below:'''

def my_function(x, y):
    return x + y
result = my_function(3, 4)  # Calling the function

class MyClass:
    def my_method(self, x, y):
        return x + y

obj = MyClass()
result = obj.my_method(3, 4)  # Calling the method

# %%
'''Q2. Explain the concept of function arguments and parameters in Python

Ans:In Python, function arguments and parameters are fundamental concepts that define how data is passed to and received by a function. Understanding the distinction and how they work is crucial for writing effective Python code.

1. Function Parameters:
Parameters are the variables listed in a function definition that specify what kind of data the function expects to receive when it is called.
They act as placeholders for the values (arguments) that will be passed into the function.


2.Function Arguments:
Arguments are the actual values or data passed to the function when it is called. These values are assigned to the corresponding parameters.
When we call a function, we pass arguments that correspond to the function's parameters.

An example is given below'''

def add(a, b):  # 'a' and 'b' are parameters
    return a + b
#Here, a and b are parameters of the add function. They are placeholders for the values that will be passed to the function when it is called.

result = add(3, 4)  # 3 and 4 are arguments

#In this example, 3 and 4 are arguments passed to the add function. They are assigned to the parameters a and b respectively, and the function returns their sum.

# %%
'''Q3.What are the different ways to define and call a function in Python?


Ans: In Python, there are several ways to define and call functions, each suited to different scenarios. Here’s a breakdown of the most common methods:

1. Basic Function Definition and Call

The most common way to define a function is by using the def keyword, followed by the function name, parameters, and a block of code.

Definition:

def greet(name):
    print(f"Hello, {name}!")
Call:

greet("Alice")

2. Function with Default Arguments

We can define default values for function parameters. If the argument is not provided during the call, the default value is used.

Definition:

def greet(name, message="Hello"):
    print(f"{message}, {name}!")
Call:

greet("Alice")          # Uses default message
greet("Bob", "Hi there")  # Custom message

3. Function with Variable-Length Arguments (*args)

If we don't know how many arguments will be passed to the function, we can use *args to capture a variable number of positional arguments.

Definition:

def sum_numbers(*args):
    return sum(args)
Call:

result = sum_numbers(1, 2, 3, 4)
print(result)  # Output: 10

4. Function with Keyword Arguments (**kwargs)

Similarly, **kwargs is used when we want to pass a variable number of keyword arguments (i.e., named arguments).

Definition:

def print_info(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")
Call:

print_info(name="Alice", age=25, city="New York")

5. Lambda Functions (Anonymous Functions)

Lambda functions are short, anonymous functions defined using the lambda keyword. They are usually used for simple operations that can be written in a single line.

Definition:

add = lambda x, y: x + y
Call:

result = add(3, 4)
print(result)  # Output: 7


6. Recursive Functions

A function that calls itself in order to solve smaller instances of the same problem. It must have a base case to avoid infinite recursion.

Definition:

def factorial(n):
    if n == 0:  # Base case
        return 1
    else:
        return n * factorial(n - 1)
Call:
python
Copy
print(factorial(5))  # Output: 120

7. Function with Named Parameters

We can specify the parameters by their names when calling a function, allowing for a more flexible function call (often used with default arguments or **kwargs).

Definition:

def greet(name, message="Hello"):
    print(f"{message}, {name}!")
Call:

greet(name="Alice", message="Good morning")  # Named arguments

8. Function Assigned to a Variable

In Python, functions are first-class objects, meaning we can assign a function to a variable and call it through that variable.

Definition:

def add(x, y):
    return x + y

addition = add  # Assign function to a variable

Call:
result = addition(3, 4)  # Call through the variable
print(result)  # Output: 7

9. Calling Functions as Part of Expressions

Functions can also be part of larger expressions or chained together in Python.

Example:
python
Copy
def square(x):
    return x * x

def add(x, y):
    return x + y

result = add(square(3), square(4))  # Chaining function calls
print(result)  # Output: 9 + 16 = 25

# %%
'''Q4. What is the purpose of return statement in Python?

Ans:  The return statement in Python is used to exit a function and optionally return a value from the function to the caller.
It serves several important purposes in Python functions:

The **`return`** statement in Python is used to **exit** a function and optionally return a value from the function to the caller. It serves several important purposes in Python functions:

### 1. **Exit the Function**:
When the `return` statement is executed, it immediately terminates the function's execution, regardless of where it is in the function. No further code in the function will be executed after the `return` statement is encountered.

#### Example:
def greet(name):
    print("Hello, " + name)
    return  # Exits the function
    print("This won't be printed")

greet("Alice")  # Output: Hello, Alice
```

In this example, the `return` statement exits the function immediately after printing the greeting. The second `print` statement is never executed.

### 2. **Return a Value**:
The `return` statement can also be used to send a value back to the caller. This allows us to return the result of a computation,
for example, so it can be used or stored by the calling code.

#### Example:
def add(x, y):
    return x + y

result = add(3, 4)
print(result)  # Output: 7
```

In this example, the function `add` returns the sum of `x` and `y`. The value `7` is returned to the calling code and stored in the variable `result`, which is then printed.

### 3. **Returning Multiple Values**:
Python allows us to return multiple values from a function by separating them with commas. The values are returned as a tuple.

#### Example:

def get_coordinates():
    return 10, 20  # Returns a tuple (10, 20)

x, y = get_coordinates()  # Unpacking the returned tuple
print(x, y)  # Output: 10 20
```

Here, the function returns two values, `10` and `20`, which are automatically packed into a tuple. When calling the function, we unpack them into the variables `x` and `y`.

### 4. **Returning `None`**:
If a function does not explicitly include a `return` statement, or if it uses `return` without any value, Python implicitly returns `None`. This is useful when a function's primary purpose is to perform actions, and there is no need to return a specific value.

## Example
def greet(name):
    print("Hello, " + name)

result = greet("Alice")
print(result)  # Output: None
```

In this case, the `greet` function doesn't return anything, so Python returns `None` by default.

### Summary of the Purpose of `return`:
- **Exit the function**: Stops the function’s execution and returns control to the caller.
- **Return a value**: Sends a value back to the caller for further use.
- **Multiple values**: Can return multiple values as a tuple.
- **Implicit `None`**: If no `return` is used, Python implicitly returns `None`.

Thus, the `return` statement is crucial for controlling the flow of a program, allowing you to send computed results or
 outcomes back to the caller and exit the function properly.    '''

# %%
'''Q5. What are iterators in Python and how  they differ from iterables?

Ans:
      Aspect	                        Iterable	                                                                              Iterator

    Definition	      An object that can be iterated over (like a list, tuple, string).               	An object that performs the actual iteration over the iterable.

    Methods	                Must implement __iter__() method.                                            Must implement both __iter__() and __next__() methods.

    State	                Does not track iteration state.	                                              Tracks the current position in the iteration.

      Usage	                    Can be used in for loops directly.	                              Needs to be explicitly created from an iterable using iter() and used with next().

    Exhaustion	      An iterable can be reused (iteration can start over).	                              An iterator gets exhausted once all items have been iterated over.


    An example is given as below:'''

    # Iterable: A list
my_list = [10, 20, 30]

# Convert iterable to iterator
iterator = iter(my_list)

# Iterating over the iterator
print(next(iterator))  # Output: 10
print(next(iterator))  # Output: 20
print(next(iterator))  # Output: 30

# The iterator is now exhausted, and calling next() again will raise StopIteration
# print(next(iterator))  # Uncommenting this will raise StopIteration
# Out:
# 10
# 20
# 30

# %%
'''Q6.Explain the concept of generators in Python and how they are defined.

Ans:A generator in Python is a special type of iterator that allows you to iterate over a potentially large sequence of data,
but it doesn't store the entire sequence in memory at once. Instead, it generates items one at a time on-the-fly, which can be more memory-efficient,
especially for large datasets.

Generators are defined using generator functions or generator expressions.

1. Generator Functions

A generator function is a function that uses the yield keyword to produce a sequence of values,
instead of using return to return a single value. When a generator function is called, it returns an iterator that can be used to iterate over the generated values.

The yield statement allows the function to return a value and remember its state, so it can resume where it left off when next() is called again.
The function's execution is paused at each yield statement and resumed from there on the next call to next().

Defining a Generator Function:

def count_up_to(max):
    count = 1
    while count <= max:
        yield count  # Return the current value and pause the function
        count += 1  # The function resumes here on the next iteration
Using a Generator Function:

counter = count_up_to(5)

print(next(counter))  # Output: 1
print(next(counter))  # Output: 2
print(next(counter))  # Output: 3
print(next(counter))  # Output: 4
print(next(counter))  # Output: 5
print(next(counter))  # Raises StopIteration, because the generator is exhausted
In this example:

When the generator function count_up_to(5) is called, it doesn't immediately execute. Instead, it returns a generator object (counter).
Each time next(counter) is called, the function executes until it reaches the yield statement, at which point it yields a value and pauses.
After all values are yielded, calling next() again raises a StopIteration exception because the generator is exhausted.

2. Generator Expressions

A generator expression is a compact way to define a generator without needing to write a full function. It’s similar to a list comprehension, but instead of producing a list, it produces a generator.

Defining a Generator Expression:

squares = (x * x for x in range(5))
In this example:

The generator expression (x * x for x in range(5)) creates a generator that produces the squares of numbers from 0 to 4.
Unlike a list comprehension, it doesn’t generate and store all the values at once. It produces values lazily when iterated.
Using a Generator Expression:
python
Copy
for square in squares:
    print(square)  # Output: 0 1 4 9 16
This iteration produces values one by one without storing them in memory all at once.'''

# %%
'''Q7. What are the advantages of using generators over regular functions?

Ans: Generators in Python provide several advantages over regular functions (which typically use `return` statements to return values). The primary benefit of using generators is their ability to handle large datasets or infinite sequences more efficiently by using **lazy evaluation**. Here’s a breakdown of the advantages of generators:

### 1. **Memory Efficiency**
- **Generators produce values one at a time**, on demand, without storing the entire sequence in memory at once. This is especially useful when dealing with large datasets or infinite sequences.
- In contrast, a regular function with a `return` statement returns all the values at once, which can lead to memory exhaustion if the data is too large.

#### Example:
Consider generating numbers from 1 to 1 million.

- **With a generator**:

  def generate_numbers():
      for i in range(1, 1000001):
          yield i
  ```
  - Here, the generator produces one number at a time, and only the current number needs to be in memory.

- **Without a generator** (using a regular function with `return`):
  def generate_numbers():
      return [i for i in range(1, 1000001)]  # All numbers are stored in memory
  ```
  - In this case, the list containing 1 million numbers is fully stored in memory at once, which could consume a lot of memory.

### 2. **Improved Performance for Large Sequences**
- Because generators generate values **on-the-fly**, they allow for **faster execution** for large sequences, as they avoid the overhead of creating and storing a large data structure like a list.
- For example, if we just need to process large data one item at a time (such as reading from a file or processing elements in a large collection), a generator is much more efficient than creating a complete list or other collection in memory.

### 3. **Lazy Evaluation (On-demand Value Generation)**
- With generators, **values are generated only when needed**, which can save both time and memory. This "lazy evaluation" means that the computation and memory usage are deferred until the value is actually requested.
- This is particularly useful when we don't need to iterate over the entire sequence, or if you're iterating over an **infinite sequence**.

#### Example:
A generator that generates an infinite sequence:
```python
def infinite_counter(start=0):
    while True:
        yield start
        start += 1

counter = infinite_counter()
for _ in range(5):
    print(next(counter))  # Output: 0 1 2 3 4
```
- The generator never creates all the numbers at once. It only produces the next value when asked, making it suitable for potentially infinite sequences.

### 4. **Convenience and Simplicity**
- Writing a generator function is **more concise and easier** than manually creating an iterator class with `__iter__()` and `__next__()` methods.
- You can create a generator function with just the `yield` keyword, which makes the code cleaner and more readable.

#### Example:
A regular function requires more effort for creating an iterator manually:
class Countdown:
    def __init__(self, start):
        self.start = start

    def __iter__(self):
        self.current = self.start
        return self

    def __next__(self):
        if self.current > 0:
            self.current -= 1
            return self.current + 1
        else:
            raise StopIteration
```
- While this code works, it's more verbose and requires additional boilerplate compared to a generator.

Using a **generator function** is much simpler:
def countdown(start):
    while start > 0:
        yield start
        start -= 1
```

### 5. **Cleaner Code in Iteration**
- Generators allow you to **iterate over large sequences without needing an explicit loop setup** or maintaining an iterator object.
- They are naturally integrated with Python’s `for` loop, which automatically handles the `StopIteration` exception when the sequence is exhausted.

#### Example:
Using a regular function:
def get_numbers():
    return [1, 2, 3, 4, 5]

numbers = get_numbers()
for num in numbers:
    print(num)
```
- Here, the list `numbers` is stored in memory entirely before the loop runs.

With a generator:

def get_numbers():
    yield 1
    yield 2
    yield 3
    yield 4
    yield 5

for num in get_numbers():
    print(num)
```
- The generator produces numbers one by one, without storing all values in memory.

### 6. **Infinite Sequences**
- Generators are ideal for generating **infinite sequences** because they don’t store all values at once. Instead, they generate values on-demand,
 which means we can have a generator that generates an infinite number of values.

#### Example:

def infinite_fibonacci():
    a, b = 0, 1
    while True:
        yield a
        a, b = b, a + b

fib = infinite_fibonacci()
for _ in range(10):
    print(next(fib))
```
- This will produce the first 10 Fibonacci numbers, but the generator can keep producing them indefinitely without storing the entire sequence in memory.

### 7. **State Retention**
- A generator function **remembers its state** between calls to `next()`. When `yield` is encountered, the function’s state is saved, and when `next()` is called again, execution resumes from the last `yield` point.
- This is useful for implementing algorithms that require maintaining state, such as traversing large trees or graphs, or managing stateful sequences.

### **Summary of Advantages**:
| **Advantage**                     | **Generators**                                                   | **Regular Functions**                                     |
|------------------------------------|------------------------------------------------------------------|-----------------------------------------------------------|
| **Memory Efficiency**              | Generate items on-the-fly, without storing all values in memory | Store all items in memory (e.g., return lists or data structures) |
| **Performance for Large Sequences**| Faster for large datasets or infinite sequences                  | Slower for large data sets as everything is returned at once |
| **Lazy Evaluation**                | Values are produced when requested                               | All values are computed and returned at once               |
| **Simpler Code**                   | More concise and easier to write with `yield`                    | Requires more boilerplate code (e.g., implementing iterators manually) |
| **Infinite Sequences**             | Can generate infinite sequences safely                           | Cannot generate infinite sequences (would consume all memory) |

### Conclusion:
Generators are a powerful tool in Python, especially when dealing with large datasets or sequences. They are **memory-efficient**, allow for **lazy evaluation**, and

often result in **simpler, more readable code**.
Regular functions are better suited for cases where we need to return all the data at once, but for
large or infinite sequences, generators provide significant performance benefits.'''

# %%
'''Q8.What is a lambda function in Python and when is it typically used?

Ans: A lambda function in Python is a small, anonymous function that is defined using the lambda keyword. Unlike regular functions defined with the def keyword, lambda functions are often used for simple operations and are typically used when a short, throwaway function is required.

Syntax of a Lambda Function
The basic syntax of a lambda function is:


lambda arguments: expression
lambda: This is the keyword that defines the function.
arguments: These are the inputs to the lambda function (just like the parameters in a normal function).
expression: This is a single expression that is evaluated and returned by the lambda function. It cannot contain statements or multiple expressions.
Example of a Lambda Function

# A simple lambda function that adds two numbers
add = lambda x, y: x + y

# Calling the lambda function
result = add(5, 3)
print(result)  # Output: 8
In this example, the lambda function takes two parameters, x and y, and returns their sum. The function is assigned to the variable add, and then called like a regular function.

Use cases where lambda functions are typically used:

For short, one-liner functions that are used only once or twice.

In higher-order functions like map(), filter(), and sorted(), where we need a simple function to apply to elements.

As a callback function or event handler in GUI programming or frameworks that require a function passed as an argument.
For simple transformations or conditions that don’t need full function definitions.

Example Summary:

# Using lambda in map, filter, and sorted
numbers = [1, 2, 3, 4, 5]

# Map example: Square each number
squares = list(map(lambda x: x**2, numbers))

# Filter example: Get even numbers
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))

# Sorted example: Sort by the second item in a tuple
pairs = [(1, 'one'), (3, 'three'), (2, 'two')]
sorted_pairs = sorted(pairs, key=lambda x: x[1])

# Output
print(squares)       # [1, 4, 9, 16, 25]
print(even_numbers)  # [2, 4]
print(sorted_pairs)  # [(1, 'one'), (2, 'two'), (3, 'three')]
Conclusion:
Lambda functions are a powerful and concise feature in Python. They are best used for small, throwaway functions
or when we need a function for a short duration, especially in higher-order functions like map(), filter(), or sorted().
However, for more complex logic or when readability is a concern, regular functions defined with def are often a better choice. '''

# %%
'''Q9. Explain the purpose and usage of the `map()` function in Python.

Ans:The map() function in Python is used to apply a specified function to each item in an iterable (such as a list, tuple, or set)
 and return an iterator (map object) that produces the results. It is often used for transforming or processing each element of an
 iterable based on a function.

Syntax of map()
map(function, iterable, ...)
function: A function that will be applied to each element of the iterable.
iterable: An iterable (e.g., list, tuple) whose elements will be passed to the function.
We can also pass multiple iterables to map(), in which case the function should accept as many arguments as there are iterables.

How map() Works

map() applies the given function to each item of the iterable(s) and returns an iterator that produces the results.
The output is a map object, which is an iterable, and can be converted to a list, tuple, or any other collection type.
Basic Usage
Single Iterable Example: Applying a function to each item in a list:

numbers = [1, 2, 3, 4, 5]

# Function to square a number
def square(x):
    return x ** 2

# Apply the function to each element using map()
squared_numbers = map(square, numbers)

# Convert the result to a list and print
print(list(squared_numbers))  # Output: [1, 4, 9, 16, 25]
Using a Lambda Function: You can use a lambda function (anonymous function) for simplicity:

numbers = [1, 2, 3, 4, 5]

# Using a lambda function to square each number
squared_numbers = map(lambda x: x ** 2, numbers)

print(list(squared_numbers))  # Output: [1, 4, 9, 16, 25]
Multiple Iterables: If you pass multiple iterables to map(), the function must accept as many arguments as there are iterables. The iteration stops when the shortest iterable is exhausted.

numbers1 = [1, 2, 3]
numbers2 = [4, 5, 6]

# Function to add elements from two lists
def add(x, y):
    return x + y

# Apply the function to each pair of elements from the two lists
summed_numbers = map(add, numbers1, numbers2)

print(list(summed_numbers))  # Output: [5, 7, 9]
Alternatively, you can use a lambda function:

summed_numbers = map(lambda x, y: x + y, numbers1, numbers2)
print(list(summed_numbers))  # Output: [5, 7, 9]

Key Points About map()

Efficient Memory Usage: map() returns an iterator instead of a list, which means it doesn't create the entire list in memory. This is useful when working with large datasets.
Function Application: The function you provide to map() is applied to each element, and we can use built-in functions, user-defined functions, or lambdas.
Return Type: map() returns an iterator, so we need to explicitly convert it to a list, tuple, or another type if we need to see the results.

# %%
'''Q10.What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?

Ans:
1. map()

Purpose: Applies a function to each item in an iterable (e.g., list, tuple) and returns a new iterable with the transformed items.
Usage:
numbers = [1, 2, 3, 4]
squared = map(lambda x: x ** 2, numbers)  # Squares each number
print(list(squared))  # Output: [1, 4, 9, 16]
Key Points:
Transforms each element in the iterable.
Returns a map object (convertible to list, tuple, etc.).

2. filter()

Purpose: Filters elements from an iterable based on whether they satisfy a condition (return True for a given function).
Usage:
numbers = [1, 2, 3, 4, 5]
even_numbers = filter(lambda x: x % 2 == 0, numbers)  # Keeps only even numbers
print(list(even_numbers))  # Output: [2, 4]
Key Points:
Removes elements that don’t satisfy the condition.
Returns a filter object (convertible to list, tuple, etc.).


3. reduce()


Purpose: Reduces an iterable to a single value by applying a function cumulatively to its elements.
Usage:
from functools import reduce
numbers = [1, 2, 3, 4]
product = reduce(lambda x, y: x * y, numbers)  # Multiplies all numbers
print(product)  # Output: 24
Key Points:
Combines elements into a single result.
Must be imported from functools (from functools import reduce).

# %% [markdown]
# Q11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list:[47,11,42,13]
#
# Ans:![Ans-Q11.jpeg](data:image/jpeg;base64,...)

# %%
# PRACTICAL QUESTION ANSWERS START HERE

#1.Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

def sum_of_evens(numbers):
    """
    Returns the sum of all even numbers in the given list.

    Args:
        numbers (list): A list of integers.

    Returns:
        int: The sum of all even numbers in the list.
    """
    return sum(num for num in numbers if num % 2 == 0)

# Example usage:
numbers=[1,2,3,4,5,6]
result = sum_of_evens(numbers)
print("Sum of even numbers:", result)
# Out:
# Sum of even numbers: 12

# %%
#2.Create a Python function that accepts a string and returns the reverse of that string.

def reverse_string(s):
    """
    Returns the reverse of the given string.

    Args:
        s (str): The input string.

    Returns:
        str: The reversed string.
    """
    return s[::-1]

# Example usage:
text = input("Enter the required string:  ")
reversed_text = reverse_string(text)
print("Reversed string:", reversed_text)
# Out:
# Enter the required string:  Original
# Reversed string: lanigirO

# %%
#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

def square_numbers(numbers):
    """
    Returns a new list containing the squares of each number in the given list.

    Args:
        numbers (list): A list of integers.

    Returns:
        list: A list of squared integers.
    """
    return [num ** 2 for num in numbers]

# Example usage:
numbers = [1, 2, 3, 4, 5]
squared_numbers = square_numbers(numbers)
print("Squared numbers:", squared_numbers)
# Out:
# Squared numbers: [1, 4, 9, 16, 25]

# %%
#4.Write a Python function that checks if a given number is prime or not from 1 to 200.

def is_prime(number):
    """
    Checks if a given number is prime.

    Args:
        number (int): The number to check.

    Returns:
        bool: True if the number is prime, False otherwise.
    """
    if number <= 1:
        return False
    for i in range(2, int(number ** 0.5) + 1):
        if number % i == 0:
            return False
    return True

# Example usage:
for num in range(1, 201):
    if is_prime(num):
        print(f"{num} is a prime number.")
# Out:
# 2 is a prime number.
# 3 is a prime number.
# 5 is a prime number.
# 7 is a prime number.
# 11 is a prime number.
# 13 is a prime number.
# 17 is a prime number.
# 19 is a prime number.
# 23 is a prime number.
# 29 is a prime number.
# 31 is a prime number.
# 37 is a prime number.
# 41 is a prime number.
# 43 is a prime number.
# 47 is a prime number.
# 53 is a prime number.
# 59 is a prime number.
# 61 is a prime number.
# 67 is a prime number.
# 71 is a prime number.
# 73 is a prime number.
# 79 is a prime number.
# 83 is a prime number.
# 89 is a prime number.
# 97 is a prime number.
# 101 is a prime number.
# 103 is a prime number.
# 107 is a prime number.
# 109 is a prime number.
# 113 is a prime number.
# 127 is a prime number.
# 131 is a prime number.
# 137 is a prime number.
# 139 is a prime number.
# 149 is a prime number.
# 151 is a prime number.
# 157 is a prime number.
# 163 is a prime number.
# 167 is a prime number.
# 173 is a prime number.
# 179 is a prime number.
# ...

# %%
#5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

class FibonacciIterator:
    """
    An iterator class to generate the Fibonacci sequence up to a specified number of terms.
    """
    def __init__(self, num_terms):
        """
        Initializes the iterator.

        Args:
            num_terms (int): The number of terms in the Fibonacci sequence to generate.
        """
        self.num_terms = num_terms
        self.current_term = 0
        self.a, self.b = 0, 1

    def __iter__(self):
        """
        Returns the iterator object itself.
        """
        return self

    def __next__(self):
        """
        Returns the next number in the Fibonacci sequence.
        """
        if self.current_term >= self.num_terms:
            raise StopIteration
        if self.current_term == 0:
            self.current_term += 1
            return self.a
        elif self.current_term == 1:
            self.current_term += 1
            return self.b
        else:
            self.a, self.b = self.b, self.a + self.b
            self.current_term += 1
            return self.a

# Example usage:
x=input("No of terms in the Fibonacci series")
d=int(x)
fib_iterator = FibonacciIterator(d)
for num in fib_iterator:
    print(num, end=" ")
# Out:
# No of terms in the Fibonacci series10
# 0 1 1 1 2 3 5 8 13 21

# %%
#6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

def powers_of_two(max_exponent):
    """
    Yields the powers of 2 up to the given exponent.

    Args:
        max_exponent (int): The maximum exponent.

    Yields:
        int: 2 raised to the current exponent.
    """
    for exponent in range(max_exponent + 1):
        yield 2 ** exponent

# Example usage:
c=input("Upto power of 2 is required in the exponent?")
d=int(c)
for power in powers_of_two(d):
    print(power, end=" ")
# Out:
# Upto power of 2 is required in the exponent?10
# 1 2 4 8 16 32 64 128 256 512 1024

# %%
#7. Implement a generator function that reads a file line by line and yields each line as a string.

def read_file_line_by_line(file_path):
    """
    A generator function that reads a file line by line and yields each line.

    Args:
        file_path (str): The path to the file to be read.

    Yields:
        str: The next line in the file.
    """
    try:
        with open(file_path, 'r') as file:
            for line in file:
                yield line.rstrip('\n')  # Strips the newline character
    except FileNotFoundError:
        print(f"Error: The file at {file_path} was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage:
file_path = 'example.txt'  # Replace with the path to your file
for line in read_file_line_by_line(file_path):
    print(line)


def create_text_file(file_name, content):
    """
    Creates a text file and writes the given content to it.

    Args:
        file_name (str): The name of the file to create.
        content (str): The content to write to the file.
    """
    with open(file_name, 'w') as file:
        file.write(content)

# Example usage:
file_name = "example.txt"
content = "Hello, this is a sample text file created in Python.\nThis is the second line.\nThis is the 3rd and the last line"
create_text_file(file_name, content)
# Out:
# Hello, this is a sample text file created in Python.
# This is the second line.
#  This is the 3rd and the last line

# %%
#8.Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# List of tuples
tuples_list = [(1, 3), (4, 1), (2, 5), (7, 2)]

# Sorting the list using a lambda function
sorted_list = sorted(tuples_list, key=lambda x: x[1])

# Output the result
print("Original list:", tuples_list)
print("Sorted list based on second element:", sorted_list)
# Out:
# Original list: [(1, 3), (4, 1), (2, 5), (7, 2)]
# Sorted list based on second element: [(4, 1), (7, 2), (1, 3), (2, 5)]

# %%
#9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

def celsius_to_fahrenheit(celsius):
    """
    Converts a temperature from Celsius to Fahrenheit.

    Args:
        celsius (float): Temperature in Celsius.

    Returns:
        float: Temperature in Fahrenheit.
    """
    return (celsius * 9/5) + 32

# List of temperatures in Celsius
celsius_temperatures = [0, 20, 37, 100]

# Convert to Fahrenheit using map()
fahrenheit_temperatures = list(map(celsius_to_fahrenheit, celsius_temperatures))

# Output the results
print("Celsius temperatures:", celsius_temperatures)
print("Fahrenheit temperatures:", fahrenheit_temperatures)
# Out:
# Celsius temperatures: [0, 20, 37, 100]
# Fahrenheit temperatures: [32.0, 68.0, 98.6, 212.0]

# %%
#10.Create a Python program that uses `filter()` to remove all the vowels from a given string.

def is_not_vowel(char):
    """
    Checks if a character is not a vowel.

    Args:
        char (str): A single character.

    Returns:
        bool: True if the character is not a vowel, False otherwise.
    """
    vowels = 'aeiouAEIOU'
    return char not in vowels

def remove_vowels(input_string):
    """
    Removes all vowels from the given string.

    Args:
        input_string (str): The input string.

    Returns:
        str: The string with vowels removed.
    """
    return ''.join(filter(is_not_vowel, input_string))

# Example usage
input_string = "Hello, World!"
result = remove_vowels(input_string)
print("Original string:", input_string)
print("String without vowels:", result)
# Out:
# Original string: Hello, World!
# String without vowels: Hll, Wrld!

# %%
'''Q11. Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:

Order Number             Book Title and Author                    Quantity                Price Per Item

   34587               Learning Python, Mark Lutz                     4                        40.95

   98762               Programming Python, Mark Lutz                  5                        56.8

   77226              Head First Python, Paul Barry                   3                        32.95

   88112            Einfuhrung in Python3, Bernd Klein                3                        24.99



Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and
the product of the price per item and the quantity. The product should be increased by 10,- € if the value
of the order is smaller than 100,00 €. Write a Python program using lambda and map.'''

#ANSWER:

# List of orders
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.8],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einfuhrung in Python3, Bernd Klein", 3, 24.99],
]

# Using map and lambda to calculate the order totals
order_totals = list(map(
    lambda order: (
        order[0],  # Order number
        order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0)  # Total with surcharge
    ),
    orders
))

# Print the result
print("Order Totals:", order_totals)
# Out:
# Order Totals: [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
